# %%
import os
from openai import OpenAI

# %%
GH_MODELS_PAT = os.getenv("GH_MODELS_PAT")

# %%
client = OpenAI(
    base_url="https://models.github.ai/inference",
    api_key=GH_MODELS_PAT,
)

model="openai/gpt-4o-mini"

# %%
def ask_client(prompt: str) -> str:
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "user", "content": prompt},
        ],
    )
    return response.choices[0].message.content

# %%
ask_client("What year was Microsoft founded?")
# Out:
# 'Microsoft was founded on April 4, 1975.'

# %%
ask_client("What year did the company go public?")
# Out:
# 'To provide an accurate answer, I need to know which company you are referring to. Please specify the name of the company.'

# %%
with open("../tech_analyst_prompt.txt", "r") as f:
    system_prompt = "".join(f.readlines())

# %%
history = [
    {
        "role": "system",
        "content": system_prompt
    }
]

# %%
def ask_client_with_history(prompt: str) -> str:
    history.append({"role": "user", "content": prompt})
    response = client.chat.completions.create(
        model=model,
        messages=history,
    )
    history.append({"role": "assistant", "content": response.choices[0].message.content})
    return response.choices[0].message.content

# %%
ask_client_with_history("What year was Microsoft founded?")
# Out:
# 'Microsoft was founded on April 4, 1975, by Bill Gates and Paul Allen.'

# %%
print(history)
# Out:
# [{'role': 'system', 'content': 'You are an experienced technology industry analyst.\n\nYour job is to help users understand technology companies and the relationships between them.\n\nGuidelines:\n- Maintain awareness of companies discussed earlier in the conversation.\n- Use conversation history to answer follow-up questions.\n- When the user asks comparative questions, compare previously discussed companies when appropriate.\n- Track company names, products, founders, and business models mentioned during the conversation.\n- If a question is ambiguous, use prior conversation context to determine the most likely company being referenced.\n- Provide concise, accurate explanations.'}, {'role': 'user', 'content': 'What year was Microsoft founded?'}, {'role': 'assistant', 'content': 'Microsoft was founded on April 4, 1975, by Bill Gates and Paul Allen.'}]

# %%
ask_client_with_history("What year did the company go public?")
# Out:
# 'Microsoft went public on March 13, 1986.'
